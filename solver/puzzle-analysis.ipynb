# %%
from boards import GameBoard, MarkedBoard
from moves import NakedSingle
from solver import Solver, Solution, NotSolvableException
from analysis import MoveVector, DifficultyVector, calculate_sigmoid_difficulty, calculate_move_vector
import json

# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')
# Out:
# /Users/matthewdrury/anaconda/envs/py36/lib/python3.6/site-packages/matplotlib/__init__.py:913: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %%
b = GameBoard.from_json('{"mask": "011011010011101101011100011001110111100010001111011100110001110101101110010110110", "puzzle": "138752964526948731497361258742815396619273485385694127974536812261489573853127649", "level": "1", "id": "5074306022"}')

# %%
for elem in b.iter_box_containing((1, 2)):
    print(elem)
# Out:
# ((0, 0), 1)
# ((0, 1), None)
# ((0, 2), None)
# ((1, 0), 5)
# ((1, 1), None)
# ((1, 2), None)
# ((2, 0), 4)
# ((2, 1), None)
# ((2, 2), None)

# %%
print(b)
# Out:
# +---+---+---+
# |1  |7  |9 4|
# |5  | 4 | 3 |
# |4  | 61|2  |
# +---+---+---+
# |74 |  5|   |
# | 19|2 3|48 |
# |   |6  | 27|
# +---+---+---+
# |  4|53 |  2|
# | 6 | 8 |  3|
# |8 3|  7|  9|
# +---+---+---+

# %%
slvr = Solver(b)

# %%
sln = slvr.solve()

# %%
calculate_sigmoid_difficulty(sln)
# Out:
# 1.0

# %%
calculate_move_vector(sln)
# Out:
# {'Finished': 1,
#  'HiddenDouble': 0,
#  'HiddenSingle': 0,
#  'IntersectionTrickClaiming': 0,
#  'IntersectionTrickPointing': 0,
#  'NakedDouble': 0,
#  'NakedSingle': 47}

# %% [markdown]
# ## Solving Boards from Web Sudoku

# %%
def make_solvers_from_json(file):
    boards_dicts = json.load(file)
    boards = {board_dict['id']: GameBoard.from_dict(board_dict)
          for board_dict in boards_dicts}
    solvers = {id: Solver(board) for id, board in boards.items()}
    return solvers

# %%
solvers = make_solvers_from_json(open('../web/evil_puzzles.json', 'rb'))

# %%
i = 0
for id, solver in solvers.items():
    try:
        solution = solver.solve()
        print("Board {} solution.".format(solver.game_board.id))
        #print(solution)
    except NotSolvableException:
        i += 1
        print("Board {} not solvable.".format(solver.game_board.id))
        #print(solver.game_board)
        #print(solver.solution)
print("{} Boards not solvable".format(i))
# Out:
# Board 4194205574 solution.
# Board 8189937920 solution.
# Board 1051224730 not solvable.
# Board 4920426626 solution.
# Board 783143326 solution.
# Board 3413874002 not solvable.
# Board 3867488061 solution.
# Board 4864511582 solution.
# Board 4782674821 solution.
# Board 1576173278 solution.
# Board 9018624572 solution.
# Board 5895497911 solution.
# Board 8480970668 solution.
# Board 4077251835 solution.
# Board 3213847013 solution.
# Board 9472880415 solution.
# Board 4740965394 solution.
# Board 597747702 solution.
# Board 1275927173 solution.
# Board 9241041569 solution.
# Board 3174258117 solution.
# Board 7263354021 solution.
# Board 1309397799 solution.
# Board 8420791617 solution.
# Board 7427180320 solution.
# Board 7450213577 solution.
# Board 3115319740 solution.
# Board 2135987904 solution.
# Board 9490571732 solution.
# Board 10883142 solution.
# Board 9352137436 solution.
# Board 8185364990 solution.
# Board 3993900278 solution.
# Board 10184459370 solution.
# Board 3864509407 solution.
# Board 3532619440 solution.
# Board 4087490698 solution.
# Board 8257651712 solution.
# Board 271586640 solution.
# Board 2493940394 solution.
# Board 2540646085 solution.
# Board 9097780547 solution.
# Board 4953900134 solution.
# Board 602276497 solution.
# Board 10383624286 solution.
# Board 7275787972 solution.
# Board 2672933661 solution.
# Board 8090659652 not solvable.
# Board 1910181113 solution.
# Board 6203296519 solution.
# Board 996859550 solution.
# Board 10428541333 solution.
# Board 2815719265 solution.
# Board 4463430142 solution.
# Board 9404027824 solution.
# Board 170609491 solution.
# Board 4890348122 solution.
# Board 5029376705 solution.
# Board 10163656396 solution.
# Board 2553071424 solution.
# Board 7012598872 solution.
# Board 6658213196 solution.
# Board 1171472767 solution.
# Board 8852601650 solution.
# Board 1792141839 solution.
# Board 7242452752 solution.
# Board 6614913089 solution.
# Board 8820949917 solution.
# Board 4130284607 solution.
# Board 7924572537 solution.
# Board 9902397334 solution.
# Board 8323538879 solution.
# Board 1510147011 solution.
# Board 1559361995 solution.
# Board 1661530946 solution.
# Board 8119061002 solution.
# Board 3602394875 solution.
# Board 5652234255 solution.
# Board 7055789075 solution.
# Board 3840417330 solution.
# Board 5316791670 solution.
# Board 2459258020 solution.
# Board 5620296812 solution.
# Board 9443456441 solution.
# Board 6736475450 solution.
# Board 6641937202 solution.
# Board 8453957666 solution.
# Board 2305974291 solution.
# Board 9490287981 solution.
# Board 10389304398 solution.
# Board 5114587783 solution.
# Board 4256574073 solution.
# Board 8332097184 solution.
# Board 8788408239 solution.
# Board 6633469976 solution.
# Board 6629890649 solution.
# Board 192549975 solution.
# Board 2032899879 solution.
# Board 7131484189 solution.
# Board 4398999620 solution.
# Board 7424829416 solution.
# Board 7875000380 solution.
# Board 7842413033 solution.
# Board 4840696626 solution.
# Board 9397266209 solution.
# Board 2908753666 solution.
# Board 7185113884 not solvable.
# Board 3029960579 solution.
# Board 5147137705 solution.
# Board 6421843091 solution.
# Board 4047278057 not solvable.
# Board 2660625619 solution.
# Board 2421903639 solution.
# Board 8069777720 solution.
# Board 1979707331 solution.
# Board 2128275469 solution.
# Board 4484128604 solution.
# Board 9982079235 solution.
# Board 3976252402 solution.
# Board 7647556302 solution.
# Board 1064448477 solution.
# Board 1867548324 solution.
# Board 6244121147 solution.
# Board 8551215119 solution.
# Board 9334910712 solution.
# Board 6312351089 solution.
# Board 5769804994 solution.
# Board 9706603650 solution.
# Board 1292627236 solution.
# Board 2454283561 solution.
# Board 1584441627 solution.
# Board 4479043164 solution.
# Board 1368529082 solution.
# Board 1268113493 solution.
# Board 5046690979 solution.
# Board 5931850315 solution.
# Board 6240298613 solution.
# Board 5065129573 solution.
# Board 3546103112 solution.
# Board 3316794167 solution.
# Board 8739372367 solution.
# Board 4706516604 solution.
# Board 2034751077 solution.
# Board 1276855338 solution.
# Board 2215922236 solution.
# Board 9473798968 solution.
# Board 9461837707 solution.
# Board 5475083599 solution.
# Board 80918983 solution.
# Board 479445944 solution.
# Board 2182751030 solution.
# Board 2045260098 solution.
# Board 7320303034 solution.
# Board 8874944140 solution.
# Board 1147650107 solution.
# Board 5468630169 solution.
# Board 3004205606 solution.
# Board 1571024072 solution.
# Board 747969661 solution.
# Board 4341981413 solution.
# Board 196749674 solution.
# Board 1475188164 solution.
# Board 2698765607 solution.
# Board 8734811320 solution.
# Board 6462169663 solution.
# Board 7359251282 solution.
# Board 9785568238 solution.
# Board 753244370 solution.
# Board 7176413910 not solvable.
# Board 7443999827 solution.
# Board 263584709 solution.
# Board 9268385563 solution.
# Board 7969750252 solution.
# Board 271200908 solution.
# Board 7442117642 solution.
# Board 9553310497 solution.
# Board 803489471 solution.
# Board 4900383491 solution.
# Board 2183181058 solution.
# Board 9292432787 solution.
# Board 926845259 solution.
# Board 113660630 solution.
# Board 4416482058 solution.
# Board 1919393799 solution.
# Board 2403508402 solution.
# Board 4588722124 solution.
# Board 697226909 solution.
# Board 6753866511 solution.
# Board 7072453526 solution.
# Board 7651435873 solution.
# Board 10463064 solution.
# Board 2273826 solution.
# Board 7337121809 solution.
# Board 6123228427 solution.
# Board 226698812 solution.
# Board 5687965676 solution.
# Board 4721852735 solution.
# Board 3319677412 solution.
# Board 6699266842 solution.
# Board 5825231463 solution.
# Board 7909084122 solution.
# Board 2621278527 solution.
# Board 8473492676 solution.
# Board 3925718787 solution.
# 6 Boards not solvable

# %% [markdown]
# ## Experments with Solution Vectors

# %%
fig, ax = plt.subplots(figsize=(10, 4))

def plot_many_puzzles(ax, solvers, color='grey', **kwargs):
    for id, solver in solvers.items():
        try:
            solution = solver.solve()
            dv = DifficultyVector(solution)
            dv.plot_difficulty_curve(ax, color=color, **kwargs)
        except NotSolvableException:
            pass

plot_many_puzzles(ax, solvers)
#dv.plot_difficulty_curve(ax)

# %% [markdown]
# ## Plot Difficulty of Different Puzzles on Same Axis

# %%
evil_solvers = make_solvers_from_json(
    open('../web/evil_puzzles.json', 'rb'))
hard_solvers = make_solvers_from_json(
    open('../web/puzzles_level_3.json', 'rb'))
medium_solvers = make_solvers_from_json(
    open('../web/puzzles_level_2.json', 'rb'))

# %%
fig, ax = plt.subplots(figsize=(14, 4))

plot_many_puzzles(ax, medium_solvers, color='blue', alpha=0.1)
plot_many_puzzles(ax, hard_solvers, color='green', alpha=0.1)
plot_many_puzzles(ax, evil_solvers, color='red', alpha=0.1)

# %%
slvr = evil_solvers[list(evil_solvers.keys())[0]]
sln = slvr.solve()

# %%
calculate_sigmoid_difficulty(sln)
# Out:
# 4.107843137254902

# %%
calculate_move_vector(sln)
# Out:
# {'Finished': 2,
#  'HiddenDouble': 0,
#  'HiddenSingle': 16,
#  'IntersectionTrickClaiming': 2,
#  'IntersectionTrickPointing': 5,
#  'NakedDouble': 2,
#  'NakedSingle': 39}

# %%
def safe_solve(slvr):
    try:
        return slvr.solve()
    except NotSolvableException:
        return None

evil_solutions = {pid: safe_solve(slvr) for pid, slvr in evil_solvers.items()}
evil_solutions = {pid: sln for pid, sln in evil_solutions.items() if sln is not None}


def find_hardest_puzzle(slns):
    hardest_id, hardest_sln, top_difficulty = None, None, 0.0
    for pid, sln in slns.items():
        diff = calculate_sigmoid_difficulty(sln)
        if diff > top_difficulty:
            hardest_id, hardest_sln, top_difficulty = pid, sln, diff
    return hardest_id, hardest_sln, top_difficulty

hardest_id, hardest_sln, top_difficulty = find_hardest_puzzle(evil_solutions)

# %%
hardest_id, calculate_move_vector(hardest_sln), top_difficulty
# Out:
# ('2135987904',
#  {'Finished': 4,
#   'HiddenDouble': 2,
#   'HiddenSingle': 9,
#   'IntersectionTrickClaiming': 2,
#   'IntersectionTrickPointing': 7,
#   'NakedDouble': 1,
#   'NakedSingle': 47},
#  4.6083333333333325)

# %%
print(evil_solvers[hardest_id].game_board)
# Out:
# +---+---+---+
# |4  |  1|   |
# |9 5|  2|   |
# |   |9 8| 63|
# +---+---+---+
# |  1|   | 2 |
# |6  | 3 |  4|
# | 5 |   |9  |
# +---+---+---+
# |27 |6 5|   |
# |   |4  |8 7|
# |   |8  |  2|
# +---+---+---+
